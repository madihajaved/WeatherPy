# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library 
import requests

# import the API key 
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# Instead of using two for loops, we can use the enumerate() method as an alternative way to iterate through 
# the list of cities and retrieve both the index, and the city from the list. 

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_des
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | erdenet
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | svetlogorsk
# Processing Record 9 of Set 1 | urulga
# City not found. Skipping...
# Processing Record 10 of Set 1 | hamilton
# Processing Record 11 of Set 1 | mumford
# Processing Record 12 of Set 1 | niquelandia
# Processing Record 13 of Set 1 | siniscola
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | norman wells
# Processing Record 18 of Set 1 | libourne
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | lokosovo
# Processing Record 22 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 1 | comodoro rivadavia
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | puerto colombia
# Processing Record 27 of Set 1 | kintampo
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | airai
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | yenagoa
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 1 | san andres
# Processing Record 42 of Set 1 | ithaca
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | marzuq
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | mingaora
# Processing Record 50 of Set 1 | gandajika
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | sindand
# City not found. Skipping...
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | sibiti
# Processing Record 6 of Set 2 | cha grande
# Processing Record 7 of Set 2 | dzhankoy
# Processing Record 8 of Set 2 | novobiryusinskiy
# Processing Record 9 of Set 2 | qaqortoq
# Processing Record 10 of Set 2 | caborca
# Processing Record 11 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | harnosand
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | samana
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | belmonte
# Processing Record 18 of Set 2 | kodinsk
# Processing Record 19 of Set 2 | bolshevik
# Processing Record 20 of Set 2 | fortuna
# Processing Record 21 of Set 2 | los llanos de aridane
# Processing Record 22 of Set 2 | flin flon
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | shaoyang
# Processing Record 26 of Set 2 | kenai
# Processing Record 27 of Set 2 | waipawa
# Processing Record 28 of Set 2 | maragogi
# Processing Record 29 of Set 2 | idenao
# Processing Record 30 of Set 2 | primorsk
# Processing Record 31 of Set 2 | atbasar
# Processing Record 32 of Set 2 | lata
# Processing Record 33 of Set 2 | faya
# Processing Record 34 of Set 2 | komsomolskiy
# Processing Record 35 of Set 2 | muros
# Processing Record 36 of Set 2 | sioux lookout
# Processing Record 37 of Set 2 | serpa
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | mont-de-marsan
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | cururupu
# Processing Record 44 of Set 2 | paramonga
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | tarakan
# Processing Record 48 of Set 2 | khilok
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | severo-kurilsk
# Processing Record 2 of Set 3 | tapaua
# City not found. Skipping...
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | nagaur
# Processing Record 6 of Set 3 | itarema
# Processing Record 7 of Set 3 | maldonado
# Processing Record 8 of Set 3 | salalah
# Processing Record 9 of Set 3 | nelson bay
# Processing Record 10 of Set 3 | alta floresta
# Processing Record 11 of Set 3 | kavaratti
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | araceli
# Processing Record 16 of Set 3 | georgetown
# Processing Record 17 of Set 3 | severo-yeniseyskiy
# Processing Record 18 of Set 3 | cabo san lucas
# Processing Record 19 of Set 3 | srandakan
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 3 | kajaani
# Processing Record 24 of Set 3 | marathon
# Processing Record 25 of Set 3 | tual
# Processing Record 26 of Set 3 | halden
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | namibe
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | boyolangu
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | umea
# Processing Record 33 of Set 3 | jinchang
# Processing Record 34 of Set 3 | mponela
# Processing Record 35 of Set 3 | iquique
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | bossangoa
# Processing Record 38 of Set 3 | maracay
# Processing Record 39 of Set 3 | dongsheng
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | soyo
# Processing Record 44 of Set 3 | olga
# Processing Record 45 of Set 3 | henties bay
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | paratinga
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | mangrol
# Processing Record 50 of Set 3 | oktyabrskoye
# Processing Record 1 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 4 | saint-philippe
# Processing Record 3 of Set 4 | codrington
# Processing Record 4 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | la ronge
# Processing Record 7 of Set 4 | san jeronimo
# Processing Record 8 of Set 4 | srednekolymsk
# Processing Record 9 of Set 4 | rio gallegos
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | luwuk
# Processing Record 12 of Set 4 | esperanca
# Processing Record 13 of Set 4 | novo aripuana
# Processing Record 14 of Set 4 | inhambane
# Processing Record 15 of Set 4 | sinnamary
# Processing Record 16 of Set 4 | arlit
# Processing Record 17 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | cayenne
# Processing Record 22 of Set 4 | paris
# Processing Record 23 of Set 4 | sao joao da barra
# Processing Record 24 of Set 4 | east london
# Processing Record 25 of Set 4 | pergamino
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | plaster rock
# Processing Record 29 of Set 4 | jizan
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | broome
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | mayor pablo lagerenza
# Processing Record 34 of Set 4 | prince rupert
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 4 | pelileo
# Processing Record 38 of Set 4 | yelizovo
# Processing Record 39 of Set 4 | qeshm
# Processing Record 40 of Set 4 | margate
# Processing Record 41 of Set 4 | conil
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | barranca
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | hanmer springs
# Processing Record 47 of Set 4 | tateyama
# Processing Record 48 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 4 | nioaque
# Processing Record 50 of Set 4 | fare
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | barcelos
# Processing Record 3 of Set 5 | caldwell
# Processing Record 4 of Set 5 | shubarshi
# Processing Record 5 of Set 5 | ust-nera
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | poum
# Processing Record 8 of Set 5 | thunder bay
# Processing Record 9 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 5 | portland
# Processing Record 12 of Set 5 | mantsala
# Processing Record 13 of Set 5 | humboldt
# Processing Record 14 of Set 5 | hoquiam
# Processing Record 15 of Set 5 | mut
# Processing Record 16 of Set 5 | idil
# Processing Record 17 of Set 5 | eucaliptus
# Processing Record 18 of Set 5 | tabou
# Processing Record 19 of Set 5 | harper
# Processing Record 20 of Set 5 | pedernales
# Processing Record 21 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 5 | tilichiki
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | tutoia
# Processing Record 25 of Set 5 | westport
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | ayan
# Processing Record 29 of Set 5 | krasnozatonskiy
# Processing Record 30 of Set 5 | sao filipe
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | polewali
# Processing Record 34 of Set 5 | arman
# Processing Record 35 of Set 5 | itumba
# Processing Record 36 of Set 5 | kirs
# Processing Record 37 of Set 5 | manacapuru
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | kidal
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | fairlie
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | podzvizd
# Processing Record 46 of Set 5 | camacha
# Processing Record 47 of Set 5 | bredasdorp
# Processing Record 48 of Set 5 | tezu
# Processing Record 49 of Set 5 | marsh harbour
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | oussouye
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | richards bay
# Processing Record 4 of Set 6 | mme
# City not found. Skipping...
# Processing Record 5 of Set 6 | bjornevatn
# Processing Record 6 of Set 6 | jiayuguan
# Processing Record 7 of Set 6 | lorengau
# Processing Record 8 of Set 6 | bubaque
# Processing Record 9 of Set 6 | tromso
# Processing Record 10 of Set 6 | touros
# Processing Record 11 of Set 6 | gambiran
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | dikson
# Processing Record 14 of Set 6 | mogadishu
# Processing Record 15 of Set 6 | jalu
# Processing Record 16 of Set 6 | karla
# Processing Record 17 of Set 6 | khorinsk
# Processing Record 18 of Set 6 | shimoda
# Processing Record 19 of Set 6 | grand gaube
# Processing Record 20 of Set 6 | usakos
# Processing Record 21 of Set 6 | kulhudhuffushi
# Processing Record 22 of Set 6 | kitgum
# Processing Record 23 of Set 6 | plettenberg bay
# Processing Record 24 of Set 6 | moindou
# Processing Record 25 of Set 6 | buala
# Processing Record 26 of Set 6 | soubre
# Processing Record 27 of Set 6 | daru
# Processing Record 28 of Set 6 | acandi
# Processing Record 29 of Set 6 | tigil
# Processing Record 30 of Set 6 | dinajpur
# Processing Record 31 of Set 6 | kudahuvadhoo
# Processing Record 32 of Set 6 | walvis bay
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | umm kaddadah
# Processing Record 35 of Set 6 | saint-denis
# Processing Record 36 of Set 6 | kropotkin
# Processing Record 37 of Set 6 | frontera
# Processing Record 38 of Set 6 | umm lajj
# Processing Record 39 of Set 6 | kyzyl-oktyabr
# Processing Record 40 of Set 6 | port keats
# Processing Record 41 of Set 6 | kwinana
# Processing Record 42 of Set 6 | nicoya
# Processing Record 43 of Set 6 | shumskiy
# Processing Record 44 of Set 6 | kutum
# Processing Record 45 of Set 6 | noumea
# Processing Record 46 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 47 of Set 6 | tura
# Processing Record 48 of Set 6 | garmisch-partenkirchen
# Processing Record 49 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 6 | sohag
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | gubkinskiy
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | pangkalanbuun
# Processing Record 5 of Set 7 | vila franca do campo
# Processing Record 6 of Set 7 | quatre cocos
# Processing Record 7 of Set 7 | reo
# Processing Record 8 of Set 7 | aksu
# Processing Record 9 of Set 7 | ratnagiri
# Processing Record 10 of Set 7 | laguna
# Processing Record 11 of Set 7 | voyvozh
# Processing Record 12 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 13 of Set 7 | upata
# Processing Record 14 of Set 7 | kivsharivka
# Processing Record 15 of Set 7 | bambanglipuro
# Processing Record 16 of Set 7 | ribeira grande
# Processing Record 17 of Set 7 | saskylakh
# Processing Record 18 of Set 7 | isla mujeres
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | fukuma
# Processing Record 21 of Set 7 | guerrero negro
# Processing Record 22 of Set 7 | axim
# Processing Record 23 of Set 7 | acarau
# Processing Record 24 of Set 7 | leopold
# Processing Record 25 of Set 7 | tarko-sale
# Processing Record 26 of Set 7 | montepuez
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | boyabat
# Processing Record 30 of Set 7 | cockburn town
# Processing Record 31 of Set 7 | zeya
# Processing Record 32 of Set 7 | misratah
# Processing Record 33 of Set 7 | nokaneng
# Processing Record 34 of Set 7 | cozumel
# Processing Record 35 of Set 7 | belozerskoye
# Processing Record 36 of Set 7 | vangaindrano
# Processing Record 37 of Set 7 | iqaluit
# Processing Record 38 of Set 7 | morant bay
# Processing Record 39 of Set 7 | wamba
# Processing Record 40 of Set 7 | ulladulla
# Processing Record 41 of Set 7 | port hedland
# Processing Record 42 of Set 7 | avera
# Processing Record 43 of Set 7 | kilindoni
# Processing Record 44 of Set 7 | ambulu
# Processing Record 45 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 7 | nhulunbuy
# Processing Record 47 of Set 7 | birjand
# Processing Record 48 of Set 7 | raudeberg
# Processing Record 49 of Set 7 | ulfborg
# Processing Record 50 of Set 7 | aromashevo
# Processing Record 1 of Set 8 | yulara
# Processing Record 2 of Set 8 | sarangani
# Processing Record 3 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 8 | tahe
# Processing Record 5 of Set 8 | khorramshahr
# Processing Record 6 of Set 8 | nouadhibou
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | sao lourenco do sul
# Processing Record 9 of Set 8 | asau
# Processing Record 10 of Set 8 | cooma
# Processing Record 11 of Set 8 | opelousas
# Processing Record 12 of Set 8 | bambous virieux
# Processing Record 13 of Set 8 | deputatskiy
# Processing Record 14 of Set 8 | hofn
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 8 | sao felix do xingu
# Processing Record 18 of Set 8 | myaundzha
# Processing Record 19 of Set 8 | fairbanks
# Processing Record 20 of Set 8 | chino valley
# Processing Record 21 of Set 8 | solyanka
# Processing Record 22 of Set 8 | sola
# Processing Record 23 of Set 8 | dalupaon
# Processing Record 24 of Set 8 | kahului
# Processing Record 25 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 8 | kaa-khem
# Processing Record 27 of Set 8 | bosaso
# Processing Record 28 of Set 8 | moyale
# Processing Record 29 of Set 8 | ouesso
# Processing Record 30 of Set 8 | kieta
# Processing Record 31 of Set 8 | naftalan
# Processing Record 32 of Set 8 | totma
# Processing Record 33 of Set 8 | acapulco
# Processing Record 34 of Set 8 | krasnoturansk
# Processing Record 35 of Set 8 | guiglo
# Processing Record 36 of Set 8 | umtata
# Processing Record 37 of Set 8 | ankazobe
# Processing Record 38 of Set 8 | bowling green
# Processing Record 39 of Set 8 | cody
# Processing Record 40 of Set 8 | halifax
# Processing Record 41 of Set 8 | malaya purga
# Processing Record 42 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 8 | roebourne
# Processing Record 44 of Set 8 | tuatapere
# Processing Record 45 of Set 8 | omsukchan
# Processing Record 46 of Set 8 | mitchell
# Processing Record 47 of Set 8 | kaitangata
# Processing Record 48 of Set 8 | rafai
# Processing Record 49 of Set 8 | mana
# Processing Record 50 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 9 | pangnirtung
# Processing Record 2 of Set 9 | byron bay
# Processing Record 3 of Set 9 | kruisfontein
# Processing Record 4 of Set 9 | lebu
# Processing Record 5 of Set 9 | ust-kut
# Processing Record 6 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 9 | zolotinka
# City not found. Skipping...
# Processing Record 8 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | santa cruz do capibaribe
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | samarinda
# Processing Record 15 of Set 9 | san policarpo
# Processing Record 16 of Set 9 | ciras
# City not found. Skipping...
# Processing Record 17 of Set 9 | kupang
# Processing Record 18 of Set 9 | surskoye
# Processing Record 19 of Set 9 | hearst
# Processing Record 20 of Set 9 | santa rosa
# Processing Record 21 of Set 9 | yangshe
# Processing Record 22 of Set 9 | araouane
# Processing Record 23 of Set 9 | ahipara
# Processing Record 24 of Set 9 | gat
# Processing Record 25 of Set 9 | kirakira
# Processing Record 26 of Set 9 | dongning
# Processing Record 27 of Set 9 | the pas
# Processing Record 28 of Set 9 | pipri
# Processing Record 29 of Set 9 | alekseyevsk
# Processing Record 30 of Set 9 | luderitz
# Processing Record 31 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 9 | saint thomas mount
# Processing Record 33 of Set 9 | dubbo
# Processing Record 34 of Set 9 | abha
# Processing Record 35 of Set 9 | road town
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | saint-joseph
# Processing Record 38 of Set 9 | karratha
# Processing Record 39 of Set 9 | ust-maya
# Processing Record 40 of Set 9 | bilma
# Processing Record 41 of Set 9 | necochea
# Processing Record 42 of Set 9 | garowe
# Processing Record 43 of Set 9 | parrita
# Processing Record 44 of Set 9 | dingle
# Processing Record 45 of Set 9 | dukat
# Processing Record 46 of Set 9 | vaasa
# Processing Record 47 of Set 9 | mount isa
# Processing Record 48 of Set 9 | matara
# Processing Record 49 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 9 | pak chong
# Processing Record 1 of Set 10 | sangar
# Processing Record 2 of Set 10 | nazarovo
# Processing Record 3 of Set 10 | kurilsk
# Processing Record 4 of Set 10 | balabac
# Processing Record 5 of Set 10 | puerto leguizamo
# Processing Record 6 of Set 10 | tucumcari
# Processing Record 7 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 10 | campbell river
# Processing Record 9 of Set 10 | shubarkuduk
# Processing Record 10 of Set 10 | yumaguzino
# Processing Record 11 of Set 10 | gimli
# Processing Record 12 of Set 10 | baykit
# Processing Record 13 of Set 10 | norman
# Processing Record 14 of Set 10 | cap-aux-meules
# Processing Record 15 of Set 10 | hay river
# Processing Record 16 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 10 | terrace
# Processing Record 18 of Set 10 | sao gabriel da cachoeira
# Processing Record 19 of Set 10 | nouakchott
# Processing Record 20 of Set 10 | zyryanka
# Processing Record 21 of Set 10 | bulawayo
# Processing Record 22 of Set 10 | salta
# Processing Record 23 of Set 10 | shelburne
# Processing Record 24 of Set 10 | kavieng
# Processing Record 25 of Set 10 | myre
# Processing Record 26 of Set 10 | saint-pierre
# Processing Record 27 of Set 10 | sarai naurang
# Processing Record 28 of Set 10 | bonavista
# Processing Record 29 of Set 10 | muisne
# Processing Record 30 of Set 10 | talara
# Processing Record 31 of Set 10 | iquitos
# Processing Record 32 of Set 10 | batticaloa
# Processing Record 33 of Set 10 | dharampur
# Processing Record 34 of Set 10 | madikeri
# Processing Record 35 of Set 10 | gewane
# Processing Record 36 of Set 10 | dandong
# Processing Record 37 of Set 10 | tonshayevo
# Processing Record 38 of Set 10 | kelheim
# Processing Record 39 of Set 10 | prince albert
# Processing Record 40 of Set 10 | kungurtug
# Processing Record 41 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 10 | inongo
# Processing Record 43 of Set 10 | bathsheba
# Processing Record 44 of Set 10 | rawson
# Processing Record 45 of Set 10 | punto fijo
# Processing Record 46 of Set 10 | veraval
# Processing Record 47 of Set 10 | la esperanza
# Processing Record 48 of Set 10 | canutama
# Processing Record 49 of Set 10 | pandan
# Processing Record 50 of Set 10 | naryan-mar
# Processing Record 1 of Set 11 | hakui
# Processing Record 2 of Set 11 | yatou
# Processing Record 3 of Set 11 | oranjestad
# Processing Record 4 of Set 11 | talca
# Processing Record 5 of Set 11 | nurota
# Processing Record 6 of Set 11 | skjervoy
# Processing Record 7 of Set 11 | ketchikan
# Processing Record 8 of Set 11 | myitkyina
# Processing Record 9 of Set 11 | kismayo
# Processing Record 10 of Set 11 | bandarbeyla
# Processing Record 11 of Set 11 | saint george
# Processing Record 12 of Set 11 | jumla
# Processing Record 13 of Set 11 | isangel
# Processing Record 14 of Set 11 | apache junction
# Processing Record 15 of Set 11 | priargunsk
# Processing Record 16 of Set 11 | tenenkou
# Processing Record 17 of Set 11 | phonhong
# Processing Record 18 of Set 11 | foz
# Processing Record 19 of Set 11 | povenets
# Processing Record 20 of Set 11 | svetlyy
# Processing Record 21 of Set 11 | orodara
# Processing Record 22 of Set 11 | sao joao dos patos
# Processing Record 23 of Set 11 | ribeira brava
# Processing Record 24 of Set 11 | makakilo city
# Processing Record 25 of Set 11 | wajir
# Processing Record 26 of Set 11 | severnyy-kospashskiy
# Processing Record 27 of Set 11 | mbanza-ngungu
# Processing Record 28 of Set 11 | blagoyevo
# Processing Record 29 of Set 11 | dudinka
# Processing Record 30 of Set 11 | mawlamyine
# Processing Record 31 of Set 11 | santa isabel do rio negro
# Processing Record 32 of Set 11 | coahuayana
# Processing Record 33 of Set 11 | estelle
# Processing Record 34 of Set 11 | deer park
# Processing Record 35 of Set 11 | lovington
# Processing Record 36 of Set 11 | dong hoi
# Processing Record 37 of Set 11 | clyde river
# Processing Record 38 of Set 11 | luena
# Processing Record 39 of Set 11 | winnemucca
# Processing Record 40 of Set 11 | voznesenye
# Processing Record 41 of Set 11 | alugan
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | owando
# Processing Record 44 of Set 11 | quimper
# Processing Record 45 of Set 11 | monte alegre de minas
# Processing Record 46 of Set 11 | darhan
# Processing Record 47 of Set 11 | talnakh
# Processing Record 48 of Set 11 | broken hill
# Processing Record 49 of Set 11 | merauke
# Processing Record 50 of Set 11 | qesarya
# Processing Record 1 of Set 12 | kabompo
# Processing Record 2 of Set 12 | san patricio
# Processing Record 3 of Set 12 | vawkavysk
# Processing Record 4 of Set 12 | champerico
# Processing Record 5 of Set 12 | vila velha
# Processing Record 6 of Set 12 | springbok
# Processing Record 7 of Set 12 | launceston
# Processing Record 8 of Set 12 | praya
# Processing Record 9 of Set 12 | maceio
# Processing Record 10 of Set 12 | virginia beach
# Processing Record 11 of Set 12 | clovis
# Processing Record 12 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 12 | sosnovoborsk
# Processing Record 14 of Set 12 | normandin
# Processing Record 15 of Set 12 | souillac
# Processing Record 16 of Set 12 | camacupa
# Processing Record 17 of Set 12 | maraba
# Processing Record 18 of Set 12 | sale
# Processing Record 19 of Set 12 | lafia
# Processing Record 20 of Set 12 | vila do maio
# Processing Record 21 of Set 12 | tyukhtet
# Processing Record 22 of Set 12 | the valley
# Processing Record 23 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 12 | chateaudun
# Processing Record 25 of Set 12 | tumaco
# Processing Record 26 of Set 12 | carberry
# Processing Record 27 of Set 12 | madimba
# Processing Record 28 of Set 12 | nome
# Processing Record 29 of Set 12 | awjilah
# Processing Record 30 of Set 12 | koubia
# Processing Record 31 of Set 12 | flinders
# Processing Record 32 of Set 12 | kokorevka
# Processing Record 33 of Set 12 | amurzet
# Processing Record 34 of Set 12 | bacsalmas
# Processing Record 35 of Set 12 | jashpurnagar
# Processing Record 36 of Set 12 | malanje
# Processing Record 37 of Set 12 | tonj
# Processing Record 38 of Set 12 | te anau
# Processing Record 39 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 40 of Set 12 | tarakeswar
# Processing Record 41 of Set 12 | muli
# Processing Record 42 of Set 12 | itanagar
# Processing Record 43 of Set 12 | gravdal
# Processing Record 44 of Set 12 | el naranjo
# Processing Record 45 of Set 12 | ixtapa
# Processing Record 46 of Set 12 | stornoway
# Processing Record 47 of Set 12 | danjiangkou
# Processing Record 48 of Set 12 | mangai
# Processing Record 49 of Set 12 | iracoubo
# Processing Record 50 of Set 12 | anadyr
# Processing Record 1 of Set 13 | minab
# Processing Record 2 of Set 13 | yaan
# Processing Record 3 of Set 13 | tambura
# Processing Record 4 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 13 | rovaniemi
# Processing Record 6 of Set 13 | tazovskiy
# Processing Record 7 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 8 of Set 13 | high level
# Processing Record 9 of Set 13 | beringovskiy
# Processing Record 10 of Set 13 | aldan
# Processing Record 11 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 13 | contamana
# Processing Record 13 of Set 13 | eseka
# Processing Record 14 of Set 13 | bessonovka
# Processing Record 15 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 13 | akyab
# Processing Record 17 of Set 13 | caraquet
# Processing Record 18 of Set 13 | orlik
# Processing Record 19 of Set 13 | tuy hoa
# Processing Record 20 of Set 13 | goderich
# Processing Record 21 of Set 13 | lasa
# Processing Record 22 of Set 13 | da nang
# Processing Record 23 of Set 13 | zalesovo
# Processing Record 24 of Set 13 | bairiki
# Processing Record 25 of Set 13 | san cristobal
# Processing Record 26 of Set 13 | mehamn
# Processing Record 27 of Set 13 | vertientes
# Processing Record 28 of Set 13 | puerto carreno
# Processing Record 29 of Set 13 | mazagao
# Processing Record 30 of Set 13 | alekseyevka
# Processing Record 31 of Set 13 | rusape
# Processing Record 32 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 13 | ucluelet
# Processing Record 34 of Set 13 | galle
# Processing Record 35 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 36 of Set 13 | marienburg
# Processing Record 37 of Set 13 | makat
# Processing Record 38 of Set 13 | alegria
# Processing Record 39 of Set 13 | chimbote
# Processing Record 40 of Set 13 | kjopsvik
# Processing Record 41 of Set 13 | pochutla
# Processing Record 42 of Set 13 | lodingen
# Processing Record 43 of Set 13 | vitim
# Processing Record 44 of Set 13 | nara
# Processing Record 45 of Set 13 | salina
# Processing Record 46 of Set 13 | aksarka
# Processing Record 47 of Set 13 | bull savanna
# Processing Record 48 of Set 13 | yarmouth
# Processing Record 49 of Set 13 | praia da vitoria
# Processing Record 50 of Set 13 | lieto
# Processing Record 1 of Set 14 | peniche
# Processing Record 2 of Set 14 | adrar
# Processing Record 3 of Set 14 | luanda
# Processing Record 4 of Set 14 | seara
# Processing Record 5 of Set 14 | saint anthony
# Processing Record 6 of Set 14 | tartagal
# Processing Record 7 of Set 14 | abbeyleix
# Processing Record 8 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 14 | northam
# Processing Record 10 of Set 14 | neryungri
# Processing Record 11 of Set 14 | linjiang
# Processing Record 12 of Set 14 | tessaoua
# Processing Record 13 of Set 14 | abu samrah
# Processing Record 14 of Set 14 | yorosso
# Processing Record 15 of Set 14 | mezhgorye
# Processing Record 16 of Set 14 | kalmunai
# Processing Record 17 of Set 14 | zhuhai
# Processing Record 18 of Set 14 | outjo
# Processing Record 19 of Set 14 | rio do sul
# Processing Record 20 of Set 14 | ambon
# Processing Record 21 of Set 14 | nyurba
# Processing Record 22 of Set 14 | saurimo
# Processing Record 23 of Set 14 | beinamar
# Processing Record 24 of Set 14 | morondava
# Processing Record 25 of Set 14 | ambilobe
# Processing Record 26 of Set 14 | escanaba
# Processing Record 27 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 14 | okhotsk
# Processing Record 29 of Set 14 | baghdad
# Processing Record 30 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 14 | manakara
# Processing Record 32 of Set 14 | rocha
# Processing Record 33 of Set 14 | kot diji
# Processing Record 34 of Set 14 | recke
# Processing Record 35 of Set 14 | mapiripan
# Processing Record 36 of Set 14 | port macquarie
# Processing Record 37 of Set 14 | mahon
# Processing Record 38 of Set 14 | ferrol
# Processing Record 39 of Set 14 | pomabamba
# Processing Record 40 of Set 14 | coquimbo
# Processing Record 41 of Set 14 | melfi
# Processing Record 42 of Set 14 | auki
# Processing Record 43 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 14 | bilibino
# Processing Record 45 of Set 14 | kamenka
# Processing Record 46 of Set 14 | hastings
# Processing Record 47 of Set 14 | mukhen
# Processing Record 48 of Set 14 | kupino
# Processing Record 49 of Set 14 | ponta delgada
# Processing Record 50 of Set 14 | balzers
# Processing Record 1 of Set 15 | rochelle
# Processing Record 2 of Set 15 | honningsvag
# Processing Record 3 of Set 15 | houston
# Processing Record 4 of Set 15 | leshukonskoye
# Processing Record 5 of Set 15 | toppenish
# Processing Record 6 of Set 15 | sur
# Processing Record 7 of Set 15 | labuhan
# Processing Record 8 of Set 15 | posse
# Processing Record 9 of Set 15 | hami
# Processing Record 10 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | cardston
# Processing Record 13 of Set 15 | pulandian
# Processing Record 14 of Set 15 | mugan
# Processing Record 15 of Set 15 | samfya
# Processing Record 16 of Set 15 | kortkeros
# Processing Record 17 of Set 15 | aswan
# Processing Record 18 of Set 15 | west fargo
# Processing Record 19 of Set 15 | bajil
# Processing Record 20 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 21 of Set 15 | ozinki
# Processing Record 22 of Set 15 | puerto cabezas
# Processing Record 23 of Set 15 | markova
# Processing Record 24 of Set 15 | teya
# Processing Record 25 of Set 15 | gilgit
# Processing Record 26 of Set 15 | sambava
# Processing Record 27 of Set 15 | hannibal
# Processing Record 28 of Set 15 | kawardha
# Processing Record 29 of Set 15 | pucallpa
# Processing Record 30 of Set 15 | staphorst
# Processing Record 31 of Set 15 | america dourada
# Processing Record 32 of Set 15 | lethem
# Processing Record 33 of Set 15 | khawhai
# Processing Record 34 of Set 15 | nyuksenitsa
# Processing Record 35 of Set 15 | okoneshnikovo
# Processing Record 36 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 15 | lewiston
# Processing Record 38 of Set 15 | vengerovo
# Processing Record 39 of Set 15 | pindiga
# Processing Record 40 of Set 15 | hadrut
# Processing Record 41 of Set 15 | berberati
# Processing Record 42 of Set 15 | livingstonia
# Processing Record 43 of Set 15 | kuching
# Processing Record 44 of Set 15 | chany
# Processing Record 45 of Set 15 | killybegs
# Processing Record 46 of Set 15 | martapura
# Processing Record 47 of Set 15 | ilam
# Processing Record 48 of Set 15 | wuwei
# Processing Record 49 of Set 15 | tongliao
# Processing Record 50 of Set 15 | nieuw amsterdam
# Processing Record 1 of Set 16 | tondano
# Processing Record 2 of Set 16 | alice springs
# Processing Record 3 of Set 16 | manzanillo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Erdenet  49.0333  104.0833     21.11        71         100       16.51
# 1  Jamestown  42.0970  -79.2353     71.60        28           1       12.66
# 2     Bethel  41.3712  -73.4140     64.00        78          62        6.58
# 3     Faanui -16.4833 -151.7500     82.27        70          59        9.60
# 4     Avarua -21.2078 -159.7750     82.40        78          40        8.05
#
#   Country Current Description
# 0      MN     overcast clouds
# 1      US           clear sky
# 2      US       broken clouds
# 3      PF       broken clouds
# 4      CK    scattered clouds

# %%
# changing column order
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Erdenet      MN  49.0333  104.0833     21.11        71         100
# 1    Jamestown      US  42.0970  -79.2353     71.60        28           1
# 2       Bethel      US  41.3712  -73.4140     64.00        78          62
# 3       Faanui      PF -16.4833 -151.7500     82.27        70          59
# 4       Avarua      CK -21.2078 -159.7750     82.40        78          40
# 5  Svetlogorsk      BY  52.6333   29.7333     40.59        70          11
# 6     Hamilton      US  39.1834  -84.5333     62.01        88          90
# 7      Mumford      GH   5.2618   -0.7590     80.80        87          61
# 8  Niquelandia      BR -14.4739  -48.4597     71.15        80          33
# 9    Siniscola      IT  40.5719    9.6922     59.00        77           0
#
#    Wind Speed Current Description
# 0       16.51     overcast clouds
# 1       12.66           clear sky
# 2        6.58       broken clouds
# 3        9.60       broken clouds
# 4        8.05    scattered clouds
# 5        8.81          few clouds
# 6       11.50                mist
# 7        8.72       broken clouds
# 8        2.01    scattered clouds
# 9        8.05           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
city_data_df.to_csv("WeatherPy_Database.csv")
